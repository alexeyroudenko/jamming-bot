# %% [markdown]
# # Analyze semantic
#
# [[Semantic Collect Data Format]]
# use knowledge\refs\Semantic Collect Data Format.md

# %%
text = "Jammingbot is a fantasy about a post-apocalyptic future, when the main functions of the Internet and assistant bots are defeated and only one self-replicating bot remains, aimlessly plowing the Internet. This is a bot that has no goal, only a path."
analyzed_all_url = "https://jamming-bot.arthew0.online/api/v1/semantic/analyze_all/"
print(analyzed_all_url)
# Out:
# https://jammingbot.com/api/v1/semantic/analyze_all/
